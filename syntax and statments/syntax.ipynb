# %% [markdown]
# ### 1. Python Syntax (Rules of Writing)

# %% [markdown]
# Rule 1: No need of ;

# %%
print("Hello")
print("Welcome")
# Out:
# Hello
# Welcome

# %% [markdown]
# ### Rule 2: Indentation is IMPORTANT
#
# Python uses spaces (indentation) instead of { }
#
# Space before print is compulsory.

# %%
if 5>2:
    print("five is greatr ")
# Out:
# five is greatr

# %% [markdown]
# ### Rule 3: Case Sensitive
#
# Both are vriables

# %%
name ="chiru"
Name = "kiran"
print(name,Name)
# Out:
# chiru kiran

# %% [markdown]
# ### Rule4: No Need to decleare data type

# %%
x = 10        # int
y = 3.5       # float
z = "Hello"   # string

# %%
x = 5 
y = "john"
print(type(x))
z = float(3)
print(z)
# Out:
# <class 'int'>
# 3.0

# %%
x = 5
y = 3.14 
z = "Hello"
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
