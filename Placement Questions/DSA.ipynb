# %% [markdown]
# ### Find largest number

# %%
arr = [10, 20, 30, 40, 50]

largest = arr[0]

for i in range(len(arr)):
    if arr[i] > largest:
        largest = arr[i]

print("Largest element is:", largest)
# Out:
# Largest element is: 50

# %% [markdown]
# ### find second largest number

# %%
arr = [10, 20, 30, 40, 50]

largest = second = 0

for i in arr:
    if i > largest:
        second = largest
        largest = i
    elif i > second:
        second = i

print("Second largest element:", second)
# Out:
# Second largest element: 40

# %%
arr = [10, 20, 30, 40, 50]

n = len(arr)

l = arr[0]

for i in range(1, n):
    if arr[i] > l:
        l = arr[i]

s = arr[0]

for i in range(1, n):
    if arr[i] > s and arr[i] < l:
        s = arr[i]

print("Second largest element:", s)
# Out:
# Second largest element: 40

# %%
arr=[10,20,30,40,50]
largest=arr[0]
second=-1
for i in range(1,len(arr)):
    if arr[i]>largest:
        second=largest
        largest=arr[i]
    elif arr[i]> second and arr[i] !=largest:
        second =arr[i]
print("largest elemnet:",largest)
print("Second largest element:", second)
# Out:
# largest elemnet: 50
# Second largest element: 40

# %% [markdown]
# ### frequency of non-overlapping conquerent pair in the given array

# %%
arr = [2, 3, 4, 4, 5, 7, 9, 11, 12, 15]
i = 0
while i<len(arr)-1:
    if arr[i+1] ==arr[i]+1:
        print(arr[i],arr[i+1])
        i+=2
    else:
        i+=1
# Out:
# 2 3
# 4 5
# 11 12

# %% [markdown]
# ### Write a Python program to read a number from the user and print the next greater number from the array

# %%
arr = [2, 3, 4, 5, 7, 9, 11, 12, 15]

num = int(input("Enter a number: "))

for i in arr:
    if i > num:
        print("Next greater number is:", i)
        break
# Out:
# Next greater number is: 7

# %% [markdown]
# ##                                                              (or)

# %%
def ngm(num):
    arr = [2, 3, 4, 5, 7, 9, 11, 12, 15]

    for i in arr:
        if i > num:
            print("Next greater number is:", i)
            break
    else:
        print("Itself is the greatest (or no greater number found).")

num = int(input("Enter a number: "))
ngm(num)
# Out:
# Next greater number is: 7

# %% [markdown]
# ### Write a Python program to read a name from the user, print the name, and change every alternate character to the next alphabetical character.

# %%
name = input("Enter your name: ")

result = ""

for i, ch in enumerate(name):
    if i % 2 == 1:        
        result += chr(ord(ch) + 1)
    else:
        result += ch

print("Original Name :", name)
print("Modified Name :", result)
# Out:
# Original Name : chiru
# Modified Name : ciisu

# %% [markdown]
# ## (or)

# %%
name =input("enter the name:")
for i in range(len(name)):
    if i%2==0:
        if name[i]=='z':
            print("A",end=' ')
        elif name[i] == 'z':
            print("a",emd=' ')
        else:
            print(chr(ord(name[i])+1),end=' ')
    else:
        print(name[i],end=' ')
# Out:
# 9

# %%
def change_name(name):
    for i in range(len(name)):
        if i % 2 == 0:
            if name[i] == 'Z':
                print("A", end="")
            elif name[i] == 'z':
                print("a", end="")
            else:
                print(chr(ord(name[i]) + 1), end="")
        else:
            print(name[i], end="")
    print()   

name = input("Enter the name: ")
change_name(name)
# Out:
# 30

# %% [markdown]
# ### Write a Python program to split an array into two equal halves. Check whether both halves are equal. If they are equal, check whether the numbers are even or odd.

# %%
arr = [1, 5, 1, 3, 5, -1]

mid = len(arr) // 2

fh = sum(arr[:mid])
sh = sum(arr[mid:])

if fh == sh:
    print("Both halves are equal")

    if fh % 2 == 0:
        print("Sum is Even")
    else:
        print("Sum is Odd")
else:
    print("Both halves are not equal")
# Out:
# Both halves are equal
# Sum is Odd

# %% [markdown]
# ### Tranpose matrix

# %%
r = int(input("Enter number of rows: "))
c = int(input("Enter number of columns: "))

matrix = []

print("Enter the matrix elements:")
for i in range(r):
    row = list(map(int, input().split()))
    matrix.append(row)

print("\nOriginal Matrix:")
for i in range(r):
    for j in range(c):
        print(matrix[i][j], end=" ")
    print()

print("\nTranspose Matrix:")
for i in range(c):
    for j in range(r):
        print(matrix[j][i], end=" ")
    print()
# Out:
# Enter the matrix elements:
#
# Original Matrix:
# 1 2 3
# 4 5 6
# 7 8 9
#
# Transpose Matrix:
# 1 4 7
# 2 5 8
# 3 6 9

# %% [markdown]
# ### Adding of two matrix

# %%
r = int(input("Enter number of rows: "))
c = int(input("Enter number of columns: "))
matrix1 = []
matrix2 = []
print("Enter elements of First Matrix:")
for i in range(r):
    row = list(map(int, input().split()))
    matrix1.append(row)
print("Enter elements of Second Matrix:")
for i in range(r):
    row = list(map(int, input().split()))
    matrix2.append(row)
print("\nFirst Matrix:")
for i in range(r):
    for j in range(c):
        print(matrix1[i][j], end=" ")
    print()
print("\nSecond Matrix:")
for i in range(r):
    for j in range(c):
        print(matrix2[i][j], end=" ")
    print()
print("\nSum of the Matrices:")
for i in range(r):
    for j in range(c):
        print(matrix1[i][j] + matrix2[i][j], end=" ")
    print()
# Out:
# Enter elements of First Matrix:
# Enter elements of Second Matrix:
#
# First Matrix:
# 1 2
# 4 5
#
# Second Matrix:
# 7 8
# 8 7
#
# Sum of the Matrices:
# 8 10
# 12 12

# %%
r = int(input("Rows: "))
c = int(input("Columns: "))

a = []
b = []

print("First Matrix")
for i in range(r):
    a.append(list(map(int, input().split())))

print("Second Matrix")
for i in range(r):
    b.append(list(map(int, input().split())))

for i in range(r):
    for j in range(c):
        print(a[i][j] + b[i][j], end=" ")
    print()
# Out:
# First Matrix
# Second Matrix
# 2 4
# 2 4

# %%
a = [[1,2],[3,4]]
b = [[5,6],[7,8]]                   ## Using zip() (Shortest)

for i, j in zip(a, b):
    for x, y in zip(i, j):
        print(x + y, end=" ")
    print()
# Out:
# 6 8
# 10 12

# %%
a = [[1,2],[3,4]]
b = [[5,6],[7,8]]                         ##   Using List Comprehension

result = [[a[i][j] + b[i][j] for j in range(len(a[0]))]
          for i in range(len(a))]

for row in result:
    print(row)
# Out:
# [6, 8]
# [10, 12]
