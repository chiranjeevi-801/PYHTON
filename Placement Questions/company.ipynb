# %% [markdown]
# ### 1) Check Whether a Number is Even or Odd

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("The number is Even")
else:
    print("The number is Odd")
# Out:
# The number is Even

# %%
def even_odd(n):
    if n%2==0:
        print("even")
    else:
        print("odd")
    n=int(input())
    even_odd(n)

# %%
num = 14  

if num % 2 == 0:
    print("The number is Even")
else:
    print("The number is Odd")
# Out:
# The number is Even

# %% [markdown]
# ### 2) Check Voting Eligibility

# %%
age=int(input("enter the age"))
if age >=18:
    print(" Yes elgible")
else:
    print(" Not elgible")
# Out:
#  Not elgible

# %%
age = int(input("Enter your age: "))
print("You are eligible to vote." if age >= 18 else "You are not eligible to vote.")
# Out:
# You are eligible to vote.

# %%
age = int(input("Enter your age: "))
eligibility_status = {True: "You are eligible to vote.", False: "You are not eligible to vote."}
print(eligibility_status[age >= 18])
# Out:
# You are not eligible to vote.

# %% [markdown]
# ### 3) ATM PIN Verification and Withdrawal Program

# %%
pin = 1234
balance = 5000
count = 0

while count < 4:
    amount = int(input("Enter PIN: "))

    if amount == pin:
        wdr = int(input("Enter amount to withdraw: "))

        if wdr <= balance:
            print("Successful")
            print("Balance:", balance - wdr)
        else:
            print("Insufficient Balance")
        break

    else:
        count = count + 1
        print("Wrong PIN")

if count == 4:
    print("Too many wrong PIN attempts.")
    print("Please wait for 24 hours or contact your bank.")
# Out:
# Wrong PIN
# Wrong PIN
# Wrong PIN
# Wrong PIN
# Too many wrong PIN attempts.
# Please wait for 24 hours or contact your bank.

# %% [markdown]
# ### password varifaction

# %%
username=input("enter username:")
password=input("enter password")

for i in range(3):
    u=input("username:")
    p=input("password:")
    if u==username and p==password:
        print("login successfull")
        break
    else:
        print("worng password")
else:
    print("3 attempt fail")
# Out:
# worng password
# worng password
# worng password
# 3 attempt fail
